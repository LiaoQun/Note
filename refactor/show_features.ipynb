# %%
import sys

sys.path.insert(0, R"C:\Users\user\Desktop\alfabet")
print(f"Updated sys.path: {sys.path}")
from alfabet.preprocessor import get_features, atom_featurizer, bond_featurizer
# Out:
# Updated sys.path: ['C:\\Users\\user\\Desktop\\alfabet', 'C:\\Users\\user\\Desktop\\alfabet\\alfabet', 'c:\\Users\\user\\anaconda3\\envs\\pytorch_alfabet\\python312.zip', 'c:\\Users\\user\\anaconda3\\envs\\pytorch_alfabet\\DLLs', 'c:\\Users\\user\\anaconda3\\envs\\pytorch_alfabet\\Lib', 'c:\\Users\\user\\anaconda3\\envs\\pytorch_alfabet', '', 'c:\\Users\\user\\anaconda3\\envs\\pytorch_alfabet\\Lib\\site-packages', 'c:\\Users\\user\\anaconda3\\envs\\pytorch_alfabet\\Lib\\site-packages\\win32', 'c:\\Users\\user\\anaconda3\\envs\\pytorch_alfabet\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\user\\anaconda3\\envs\\pytorch_alfabet\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\user\\Desktop\\alfabet\\refactor\\alfabet', 'c:\\Users\\user\\Desktop\\alfabet\\refactor\\alfabet', 'c:\\Users\\user\\Desktop\\alfabet\\refactor\\..\\alfabet', 'c:\\Users\\user\\Desktop\\alfabet\\refactor\\..\\alfabet']

# %%
smiles = "CCO"
features = get_features(smiles=smiles)

print(features.keys())
print("Atom features:{}".format(features['atom'].shape))
print("Bond features:{}".format(features['bond'].shape))
features
# CCO has 3 heavy atoms, 6 H atoms, and 8 bonds
# Out:
# dict_keys(['atom', 'bond_indices', 'bond', 'connectivity'])
# Atom features:(9,)
# Bond features:(16,)
# {'atom': array([ 2, 10,  6,  7,  7,  7,  7,  7,  7]),
#  'bond_indices': array([0, 2, 3, 4, 0, 1, 5, 6, 1, 7, 2, 3, 4, 5, 6, 7]),
#  'bond': array([ 2,  3,  3,  3,  2,  6,  3,  3,  7,  8,  9,  9,  9,  9,  9, 10]),
#  'connectivity': array([[0, 1],
#         [0, 3],
#         [0, 4],
#         [0, 5],
#         [1, 0],
#         [1, 2],
#         [1, 6],
#         [1, 7],
#         [2, 1],
#         [2, 8],
#         [3, 0],
#         [4, 0],
#         [5, 0],
#         [6, 1],
#         [7, 1],
#         [8, 2]])}
